# %%
import numpy as np

# %%
data1 = np.load('train_data_simulation_clean.npy')

# %%
data2 = np.load('train_data_numerical_derivatives.npy')

# %%
import matplotlib.pyplot as plt

# %%
prediction1 = -1.*data1[:,0]**3 + 1.9*data1[:,0]**2 - 0.9*data1[:,0] + 10.*data1[:,2]
prediction2 = -1.*data2[:,0]**3 + 1.9*data2[:,0]**2 - 0.9*data2[:,0] + 10.*data2[:,2]

# %%
np.mean(np.abs(prediction1-data1[:,-1]))
# Out:
# 0.00376398

# %%
np.mean(np.abs(prediction2-data2[:,-1]))
# Out:
# 0.00013426251009772272

# %%
plt.plot(data1[:,3])

# %%
plt.plot(data2[:,3])
